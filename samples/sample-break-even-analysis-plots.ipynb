# %%
import sys
sys.path.append('..')

from matplotlib import pyplot as plt
from src.analysis import break_even_analysis, comparative_statics, stochastic_bivariate_simulation, run_monte_carlo, \
    run_two_way_sensitivity_analysis
from src.config import variable_names
from src.engine import evaluate_chained_models, evaluate_variable_scenario_sweep, evaluate_expected_scenario
from src.models import ProfitModel, CostOfGoodsSoldModel, RevenueModel, FreeCashFlowModel, \
    CapitalExpenditureModel, DepreciationModel, TotalExpenseModel, NetIncomeModel, RoiModel, TotalCostModel, \
    AdvertisingEfficiencyModel
from src.variables import Orders, SellingPrice, PurchasingPrice, ItemsPerOrder, USDToRMB, Rent, TaxRate, \
    CostPerAcquisition, ConversionRate, RenderFee, TravelFee, AdvertisingCost, Expense

from src.visualization import render_break_even_dashboard, get_break_even_dataframe

# %%
variables = {variable_names.DEAL_ITEMS_PER_ORDER: ItemsPerOrder(min_value=1, max_value=5),
             variable_names.FINANCE_USD_TO_RMB: USDToRMB(expected_value=6.8, min_value=6.0, max_value=7.5),
             variable_names.DEAL_ORDERS: Orders(min_value=20, max_value=30),
             variable_names.COST_ADVERTISING: AdvertisingCost(min_value=10000, max_value=30000),
             variable_names.COST_CPA: CostPerAcquisition(min_value=12, max_value=36),
             variable_names.COST_CONVERSION_RATE: ConversionRate(min_value=0.04, max_value=0.2),
             variable_names.DEAL_PURCHASING_PRICE: PurchasingPrice(min_value=1000, max_value=2000),
             variable_names.DEAL_SELLING_PRICE: SellingPrice(min_value=3000, max_value=6000)}

cogs_model = CostOfGoodsSoldModel()
cost_model = TotalCostModel()
revenue_model = RevenueModel()
expense_model = TotalExpenseModel()
depreciation_model = DepreciationModel()
capital_expenditure_model = CapitalExpenditureModel()
net_income_model = NetIncomeModel()
profit_model = ProfitModel()
advertising_efficiency_model = AdvertisingEfficiencyModel()

# %%
break_even_analysis_report = break_even_analysis(variables, selected_variables=[variable_names.DEAL_ORDERS,
                                                                                variable_names.DEAL_SELLING_PRICE],
                                                 model_pipeline=[advertising_efficiency_model,
                                                                 cogs_model, revenue_model, cost_model,
                                                                 expense_model,
                                                                 depreciation_model, net_income_model,
                                                                 capital_expenditure_model, profit_model],
                                                 output_name=variable_names.PROFIT, goal=0)

print(get_break_even_dataframe(break_even_analysis_report, variable_names.PROFIT))
# Out:
#   Sensitivity Variable  Base (Expected)  BE (Threshold)  Safety Margin %
# 0               Profit     1.263824e+06    1.263824e+06              NaN
# 1               Orders     2.500000e+01    2.000000e+01         0.200000
# 2               Profit     1.263824e+06    8.138235e+05              NaN
# 3         SellingPrice     4.500000e+03    3.000000e+03         0.333333

# %%
render_break_even_dashboard(break_even_analysis_report, variable_names.PROFIT)
# Out:
# <style type="text/css">
# #T_a09a8  {
#   border-collapse: collapse;
#   width: 100%;
#   margin: 15px 0;
#   border: 1px solid #dee2e6;
# }
# #T_a09a8 th {
#   background-color: #f1f3f5;
#   color: #2c3e50;
#   padding: 12px 15px;
#   border-bottom: 2px solid #dee2e6;
#   text-align: right !important;
#   text-transform: uppercase;
#   font-size: 0.85rem;
# }
# #T_a09a8 td {
#   padding: 10px 15px;
#   border-bottom: 1px solid #eee;
#   text-align: right;
#   font-variant-numeric: tabular-nums;
# }
# #T_a09a8 th.col0 {
#   text-align: right !important;
# }
# #T_a09a8_row0_col0, #T_a09a8_row2_col0 {
#   text-align: right !important;
#   padding-left: 25px !important;
#   color: #6c757d;
#   font-style: italic;
#   font-size: 0.9rem;
#   border-bottom: 2px solid #dee2e6 !important;
# }
# #T_a09a8_row0_col1, #T_a09a8_row2_col1 {
#   background-color: #e7f5ff;
#   color: #2c3e50;
#   font-weight: bold;
#   border-right: 1px solid #d0ebff;
#   border-bottom: 2px solid #dee2e6 !important;
# }
# #T_a09a8_row0_col2, #T_a09a8_row2_col2 {
#   background-color: #fff3cd;
#   color: #664d03;
#   font-weight: bold;
#   border-right: 1px solid #fff3cd;
#   border-bottom: 2px solid #dee2e6 !important;
# }
# #T_a09a8_row0_col3, #T_a09a8_row2_col3 {
#   border-bottom: 2px solid #dee2e6 !important;
# }
# #T_a09a8_row1_col0, #T_a09a8_row3_col0 {
#   text-align: right !important;
#   font-weight: bold;
# }
# #T_a09a8_row1_col1, #T_a09a8_row3_col1 {
#   background-color: #4682B4;
#   color: white;
#   font-weight: bold;
# }
# #T_a09a8_row1_col2, #T_a09a8_row3_col2 {
#   background-color: #ffda6a;
#   color: #4d3a02;
#   font-weight: bold;
# }
# #T_a09a8_row1_col3, #T_a09a8_row3_col3 {
#   background-color: #2e7d32;
#   color: #ffffff;
#   font-weight: bold;
# }
# </style>
# <table id="T_a09a8">
#   <thead>
#     <tr>
#       <th id="T_a09a8_level0_col0" class="col_heading level0 col0" >Sensitivity Variable</th>
#       <th id="T_a09a8_level0_col1" class="col_heading level0 col1" >Base (Expected)</th>
#       <th id="T_a09a8_level0_col2" class="col_heading level0 col2" >BE (Threshold)</th>
#       <th id="T_a09a8_level0_col3" class="col_heading level0 col3" >Safety Margin %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a09a8_row0_col0" class="data row0 col0" >Profit</td>
#       <td id="T_a09a8_row0_col1" class="data row0 col1" >¥1,263,824</td>
#       <td id="T_a09a8_row0_col2" class="data row0 col2" >¥1,263,824</td>
#       <td id="T_a09a8_row0_col3" class="data row0 col3" ></td>
#     </tr>
#     <tr>
#       <td id="T_a09a8_row1_col0" class="data row1 col0" >Orders</td>
#       <td id="T_a09a8_row1_col1" class="data row1 col1" >25.0</td>
#       <td id="T_a09a8_row1_col2" class="data row1 col2" >20.0</td>
#       <td id="T_a09a8_row1_col3" class="data row1 col3" >20.0%</td>
#     </tr>
#     <tr>
#       <td id="T_a09a8_row2_col0" class="data row2 col0" >Profit</td>
#       <td id="T_a09a8_row2_col1" class="data row2 col1" >¥1,263,824</td>
#       <td id="T_a09a8_row2_col2" class="data row2 col2" >¥813,824</td>
#       <td id="T_a09a8_row2_col3" class="data row2 col3" ></td>
#     </tr>
#     <tr>
#       <td id="T_a09a8_row3_col0" class="data row3 col0" >SellingPrice</td>
#       <td id="T_a09a8_row3_col1" class="data row3 col1" >$4,500</td>
#       <td id="T_a09a8_row3_col2" class="data row3 col2" >$3,000</td>
#       <td id="T_a09a8_row3_col3" class="data row3 col3" >33.3%</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(break_even_analysis_report)
# Out:
# [{'BreakEvenVariable': 'Orders', 'FeasibilityStatus': 'ALWAYS_FEASIBLE', 'BreakEvenExpectedVariableValue': 25.0, 'BreakEvenExpectedResult': 1263823.5294117648, 'ThresholdVariableValue': 20.0, 'ThresholdResult': 1263823.5294117648, 'SafetyMarginPercentage': 0.2}, {'BreakEvenVariable': 'SellingPrice', 'FeasibilityStatus': 'ALWAYS_FEASIBLE', 'BreakEvenExpectedVariableValue': 4500.0, 'BreakEvenExpectedResult': 1263823.5294117648, 'ThresholdVariableValue': 3000.0, 'ThresholdResult': 813823.5294117648, 'SafetyMarginPercentage': 0.3333333333333333}]

# %%
break_even_analysis_report_higher_goal = break_even_analysis(variables,
                                                             selected_variables=[variable_names.DEAL_ORDERS,
                                                                                 variable_names.DEAL_SELLING_PRICE],
                                                             model_pipeline=[advertising_efficiency_model,
                                                                             cogs_model, revenue_model, cost_model,
                                                                             expense_model,
                                                                             depreciation_model, net_income_model,
                                                                             capital_expenditure_model,
                                                                             profit_model],
                                                             output_name=variable_names.PROFIT, goal=1000000)
print(get_break_even_dataframe(break_even_analysis_report_higher_goal, variable_names.PROFIT))
# Out:
#   Sensitivity Variable  Base (Expected)  BE (Threshold)  Safety Margin %
# 0               Profit     1.263824e+06    1.263824e+06              NaN
# 1               Orders     2.500000e+01    2.000000e+01         0.200000
# 2               Profit     1.263824e+06    1.015864e+06              NaN
# 3         SellingPrice     4.500000e+03    3.673469e+03         0.183673

# %%
render_break_even_dashboard(break_even_analysis_report_higher_goal, variable_names.PROFIT)
# Out:
# <style type="text/css">
# #T_db074  {
#   border-collapse: collapse;
#   width: 100%;
#   margin: 15px 0;
#   border: 1px solid #dee2e6;
# }
# #T_db074 th {
#   background-color: #f1f3f5;
#   color: #2c3e50;
#   padding: 12px 15px;
#   border-bottom: 2px solid #dee2e6;
#   text-align: right !important;
#   text-transform: uppercase;
#   font-size: 0.85rem;
# }
# #T_db074 td {
#   padding: 10px 15px;
#   border-bottom: 1px solid #eee;
#   text-align: right;
#   font-variant-numeric: tabular-nums;
# }
# #T_db074 th.col0 {
#   text-align: right !important;
# }
# #T_db074_row0_col0, #T_db074_row2_col0 {
#   text-align: right !important;
#   padding-left: 25px !important;
#   color: #6c757d;
#   font-style: italic;
#   font-size: 0.9rem;
#   border-bottom: 2px solid #dee2e6 !important;
# }
# #T_db074_row0_col1, #T_db074_row2_col1 {
#   background-color: #e7f5ff;
#   color: #2c3e50;
#   font-weight: bold;
#   border-right: 1px solid #d0ebff;
#   border-bottom: 2px solid #dee2e6 !important;
# }
# #T_db074_row0_col2, #T_db074_row2_col2 {
#   background-color: #fff3cd;
#   color: #664d03;
#   font-weight: bold;
#   border-right: 1px solid #fff3cd;
#   border-bottom: 2px solid #dee2e6 !important;
# }
# #T_db074_row0_col3, #T_db074_row2_col3 {
#   border-bottom: 2px solid #dee2e6 !important;
# }
# #T_db074_row1_col0, #T_db074_row3_col0 {
#   text-align: right !important;
#   font-weight: bold;
# }
# #T_db074_row1_col1, #T_db074_row3_col1 {
#   background-color: #4682B4;
#   color: white;
#   font-weight: bold;
# }
# #T_db074_row1_col2, #T_db074_row3_col2 {
#   background-color: #ffda6a;
#   color: #4d3a02;
#   font-weight: bold;
# }
# #T_db074_row1_col3 {
#   background-color: #2e7d32;
#   color: #ffffff;
#   font-weight: bold;
# }
# #T_db074_row3_col3 {
#   background-color: #d4edda;
#   color: #155724;
#   font-weight: bold;
# }
# </style>
# <table id="T_db074">
#   <thead>
#     <tr>
#       <th id="T_db074_level0_col0" class="col_heading level0 col0" >Sensitivity Variable</th>
#       <th id="T_db074_level0_col1" class="col_heading level0 col1" >Base (Expected)</th>
#       <th id="T_db074_level0_col2" class="col_heading level0 col2" >BE (Threshold)</th>
#       <th id="T_db074_level0_col3" class="col_heading level0 col3" >Safety Margin %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_db074_row0_col0" class="data row0 col0" >Profit</td>
#       <td id="T_db074_row0_col1" class="data row0 col1" >¥1,263,824</td>
#       <td id="T_db074_row0_col2" class="data row0 col2" >¥1,263,824</td>
#       <td id="T_db074_row0_col3" class="data row0 col3" ></td>
#     </tr>
#     <tr>
#       <td id="T_db074_row1_col0" class="data row1 col0" >Orders</td>
#       <td id="T_db074_row1_col1" class="data row1 col1" >25.0</td>
#       <td id="T_db074_row1_col2" class="data row1 col2" >20.0</td>
#       <td id="T_db074_row1_col3" class="data row1 col3" >20.0%</td>
#     </tr>
#     <tr>
#       <td id="T_db074_row2_col0" class="data row2 col0" >Profit</td>
#       <td id="T_db074_row2_col1" class="data row2 col1" >¥1,263,824</td>
#       <td id="T_db074_row2_col2" class="data row2 col2" >¥1,015,864</td>
#       <td id="T_db074_row2_col3" class="data row2 col3" ></td>
#     </tr>
#     <tr>
#       <td id="T_db074_row3_col0" class="data row3 col0" >SellingPrice</td>
#       <td id="T_db074_row3_col1" class="data row3 col1" >$4,500</td>
#       <td id="T_db074_row3_col2" class="data row3 col2" >$3,673</td>
#       <td id="T_db074_row3_col3" class="data row3 col3" >18.4%</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(break_even_analysis_report_higher_goal)
# Out:
# [{'BreakEvenVariable': 'Orders', 'FeasibilityStatus': 'ALWAYS_FEASIBLE', 'BreakEvenExpectedVariableValue': 25.0, 'BreakEvenExpectedResult': 1263823.5294117648, 'ThresholdVariableValue': 20.0, 'ThresholdResult': 1263823.5294117648, 'SafetyMarginPercentage': 0.2}, {'BreakEvenVariable': 'SellingPrice', 'FeasibilityStatus': 'CROSSOVER_FOUND', 'BreakEvenExpectedVariableValue': 4500.0, 'BreakEvenExpectedResult': 1263823.5294117648, 'ThresholdVariableValue': 3673.4694, 'ThresholdResult': 1015864.3494117648, 'SafetyMarginPercentage': 0.18367346666666667}]

# %%
break_even_analysis_report_highest_goal = break_even_analysis(variables,
                                                             selected_variables=[variable_names.COST_ADVERTISING,
                                                                                 variable_names.DEAL_PURCHASING_PRICE,
                                                                                 variable_names.DEAL_SELLING_PRICE,
                                                                                 variable_names.COST_CPA,
                                                                                 variable_names.COST_CONVERSION_RATE,
                                                                                 variable_names.DEAL_ITEMS_PER_ORDER],
                                                             model_pipeline=[advertising_efficiency_model,
                                                                             cogs_model, revenue_model, cost_model,
                                                                             expense_model,
                                                                             depreciation_model, net_income_model,
                                                                             capital_expenditure_model,
                                                                             profit_model],
                                                             output_name=variable_names.PROFIT, goal=1300000)
print(get_break_even_dataframe(break_even_analysis_report_highest_goal, variable_names.PROFIT))
# Out:
#    Sensitivity Variable  Base (Expected)  BE (Threshold)  Safety Margin %
# 0                Profit     1.263824e+06    1.302512e+06              NaN
# 1       AdvertisingCost     2.000000e+04    2.061224e+04        -0.030612
# 2                Profit     1.263824e+06    1.285882e+06              NaN
# 3       PurchasingPrice     1.500000e+03    1.000000e+03        -0.333333
# 4                Profit     1.263824e+06    1.309742e+06              NaN
# 5          SellingPrice     4.500000e+03    4.653061e+03        -0.034014
# 6                Profit     1.263824e+06    1.304366e+06              NaN
# 7    CostPerAcquisition     2.400000e+01    2.326530e+01        -0.030613
# 8                Profit     1.263824e+06    1.316246e+06              NaN
# 9        ConversionRate     1.200000e-01    1.249000e-01        -0.040833
# 10               Profit     1.263824e+06    1.316204e+06              NaN
# 11        ItemsPerOrder     3.000000e+00    3.122400e+00        -0.040800

# %%
render_break_even_dashboard(break_even_analysis_report_highest_goal, variable_names.PROFIT)
# Out:
# <style type="text/css">
# #T_2159f  {
#   border-collapse: collapse;
#   width: 100%;
#   margin: 15px 0;
#   border: 1px solid #dee2e6;
# }
# #T_2159f th {
#   background-color: #f1f3f5;
#   color: #2c3e50;
#   padding: 12px 15px;
#   border-bottom: 2px solid #dee2e6;
#   text-align: right !important;
#   text-transform: uppercase;
#   font-size: 0.85rem;
# }
# #T_2159f td {
#   padding: 10px 15px;
#   border-bottom: 1px solid #eee;
#   text-align: right;
#   font-variant-numeric: tabular-nums;
# }
# #T_2159f th.col0 {
#   text-align: right !important;
# }
# #T_2159f_row0_col0, #T_2159f_row2_col0, #T_2159f_row4_col0, #T_2159f_row6_col0, #T_2159f_row8_col0, #T_2159f_row10_col0 {
#   text-align: right !important;
#   padding-left: 25px !important;
#   color: #6c757d;
#   font-style: italic;
#   font-size: 0.9rem;
#   border-bottom: 2px solid #dee2e6 !important;
# }
# #T_2159f_row0_col1, #T_2159f_row2_col1, #T_2159f_row4_col1, #T_2159f_row6_col1, #T_2159f_row8_col1, #T_2159f_row10_col1 {
#   background-color: #e7f5ff;
#   color: #2c3e50;
#   font-weight: bold;
#   border-right: 1px solid #d0ebff;
#   border-bottom: 2px solid #dee2e6 !important;
# }
# #T_2159f_row0_col2, #T_2159f_row2_col2, #T_2159f_row4_col2, #T_2159f_row6_col2, #T_2159f_row8_col2, #T_2159f_row10_col2 {
#   background-color: #fff3cd;
#   color: #664d03;
#   font-weight: bold;
#   border-right: 1px solid #fff3cd;
#   border-bottom: 2px solid #dee2e6 !important;
# }
# #T_2159f_row0_col3, #T_2159f_row2_col3, #T_2159f_row4_col3, #T_2159f_row6_col3, #T_2159f_row8_col3, #T_2159f_row10_col3 {
#   border-bottom: 2px solid #dee2e6 !important;
# }
# #T_2159f_row1_col0, #T_2159f_row3_col0, #T_2159f_row5_col0, #T_2159f_row7_col0, #T_2159f_row9_col0, #T_2159f_row11_col0 {
#   text-align: right !important;
#   font-weight: bold;
# }
# #T_2159f_row1_col1, #T_2159f_row3_col1, #T_2159f_row5_col1, #T_2159f_row7_col1, #T_2159f_row9_col1, #T_2159f_row11_col1 {
#   background-color: #4682B4;
#   color: white;
#   font-weight: bold;
# }
# #T_2159f_row1_col2, #T_2159f_row5_col2, #T_2159f_row7_col2, #T_2159f_row9_col2, #T_2159f_row11_col2 {
#   background-color: #ffda6a;
#   color: #4d3a02;
#   font-weight: bold;
# }
# #T_2159f_row1_col3, #T_2159f_row5_col3, #T_2159f_row7_col3, #T_2159f_row9_col3, #T_2159f_row11_col3 {
#   background-color: #f8d7da;
#   color: #721c24;
#   font-weight: bold;
# }
# #T_2159f_row3_col2 {
#   background-color: #d99b00;
#   color: #261b00;
#   font-weight: bold;
#   border-right: 1px solid #d99b00;
# }
# #T_2159f_row3_col3 {
#   background-color: #CD5C5C;
#   color: white;
#   font-weight: bold;
# }
# </style>
# <table id="T_2159f">
#   <thead>
#     <tr>
#       <th id="T_2159f_level0_col0" class="col_heading level0 col0" >Sensitivity Variable</th>
#       <th id="T_2159f_level0_col1" class="col_heading level0 col1" >Base (Expected)</th>
#       <th id="T_2159f_level0_col2" class="col_heading level0 col2" >BE (Threshold)</th>
#       <th id="T_2159f_level0_col3" class="col_heading level0 col3" >Safety Margin %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2159f_row0_col0" class="data row0 col0" >Profit</td>
#       <td id="T_2159f_row0_col1" class="data row0 col1" >¥1,263,824</td>
#       <td id="T_2159f_row0_col2" class="data row0 col2" >¥1,302,512</td>
#       <td id="T_2159f_row0_col3" class="data row0 col3" ></td>
#     </tr>
#     <tr>
#       <td id="T_2159f_row1_col0" class="data row1 col0" >AdvertisingCost</td>
#       <td id="T_2159f_row1_col1" class="data row1 col1" >¥20,000</td>
#       <td id="T_2159f_row1_col2" class="data row1 col2" >¥20,612</td>
#       <td id="T_2159f_row1_col3" class="data row1 col3" >-3.1%</td>
#     </tr>
#     <tr>
#       <td id="T_2159f_row2_col0" class="data row2 col0" >Profit</td>
#       <td id="T_2159f_row2_col1" class="data row2 col1" >¥1,263,824</td>
#       <td id="T_2159f_row2_col2" class="data row2 col2" >¥1,285,882</td>
#       <td id="T_2159f_row2_col3" class="data row2 col3" ></td>
#     </tr>
#     <tr>
#       <td id="T_2159f_row3_col0" class="data row3 col0" >PurchasingPrice</td>
#       <td id="T_2159f_row3_col1" class="data row3 col1" >¥1,500</td>
#       <td id="T_2159f_row3_col2" class="data row3 col2" >¥1,000</td>
#       <td id="T_2159f_row3_col3" class="data row3 col3" >-33.3%</td>
#     </tr>
#     <tr>
#       <td id="T_2159f_row4_col0" class="data row4 col0" >Profit</td>
#       <td id="T_2159f_row4_col1" class="data row4 col1" >¥1,263,824</td>
#       <td id="T_2159f_row4_col2" class="data row4 col2" >¥1,309,742</td>
#       <td id="T_2159f_row4_col3" class="data row4 col3" ></td>
#     </tr>
#     <tr>
#       <td id="T_2159f_row5_col0" class="data row5 col0" >SellingPrice</td>
#       <td id="T_2159f_row5_col1" class="data row5 col1" >$4,500</td>
#       <td id="T_2159f_row5_col2" class="data row5 col2" >$4,653</td>
#       <td id="T_2159f_row5_col3" class="data row5 col3" >-3.4%</td>
#     </tr>
#     <tr>
#       <td id="T_2159f_row6_col0" class="data row6 col0" >Profit</td>
#       <td id="T_2159f_row6_col1" class="data row6 col1" >¥1,263,824</td>
#       <td id="T_2159f_row6_col2" class="data row6 col2" >¥1,304,366</td>
#       <td id="T_2159f_row6_col3" class="data row6 col3" ></td>
#     </tr>
#     <tr>
#       <td id="T_2159f_row7_col0" class="data row7 col0" >CostPerAcquisition</td>
#       <td id="T_2159f_row7_col1" class="data row7 col1" >$24.0</td>
#       <td id="T_2159f_row7_col2" class="data row7 col2" >$23.3</td>
#       <td id="T_2159f_row7_col3" class="data row7 col3" >-3.1%</td>
#     </tr>
#     <tr>
#       <td id="T_2159f_row8_col0" class="data row8 col0" >Profit</td>
#       <td id="T_2159f_row8_col1" class="data row8 col1" >¥1,263,824</td>
#       <td id="T_2159f_row8_col2" class="data row8 col2" >¥1,316,246</td>
#       <td id="T_2159f_row8_col3" class="data row8 col3" ></td>
#     </tr>
#     <tr>
#       <td id="T_2159f_row9_col0" class="data row9 col0" >ConversionRate</td>
#       <td id="T_2159f_row9_col1" class="data row9 col1" >12.00%</td>
#       <td id="T_2159f_row9_col2" class="data row9 col2" >12.49%</td>
#       <td id="T_2159f_row9_col3" class="data row9 col3" >-4.1%</td>
#     </tr>
#     <tr>
#       <td id="T_2159f_row10_col0" class="data row10 col0" >Profit</td>
#       <td id="T_2159f_row10_col1" class="data row10 col1" >¥1,263,824</td>
#       <td id="T_2159f_row10_col2" class="data row10 col2" >¥1,316,204</td>
#       <td id="T_2159f_row10_col3" class="data row10 col3" ></td>
#     </tr>
#     <tr>
#       <td id="T_2159f_row11_col0" class="data row11 col0" >ItemsPerOrder</td>
#       <td id="T_2159f_row11_col1" class="data row11 col1" >3.0</td>
#       <td id="T_2159f_row11_col2" class="data row11 col2" >3.1</td>
#       <td id="T_2159f_row11_col3" class="data row11 col3" >-4.1%</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(break_even_analysis_report_highest_goal)
# Out:
# [{'BreakEvenVariable': 'AdvertisingCost', 'FeasibilityStatus': 'CROSSOVER_FOUND', 'BreakEvenExpectedVariableValue': 20000.0, 'BreakEvenExpectedResult': 1263823.5294117648, 'ThresholdVariableValue': 20612.2449, 'ThresholdResult': 1302512.0049308825, 'SafetyMarginPercentage': -0.030612245000000076}, {'BreakEvenVariable': 'PurchasingPrice', 'FeasibilityStatus': 'UNREACHABLE', 'BreakEvenExpectedVariableValue': 1500.0, 'BreakEvenExpectedResult': 1263823.5294117648, 'ThresholdVariableValue': 1000.0, 'ThresholdResult': 1285882.3529411764, 'SafetyMarginPercentage': -0.3333333333333333}, {'BreakEvenVariable': 'SellingPrice', 'FeasibilityStatus': 'CROSSOVER_FOUND', 'BreakEvenExpectedVariableValue': 4500.0, 'BreakEvenExpectedResult': 1263823.5294117648, 'ThresholdVariableValue': 4653.0612, 'ThresholdResult': 1309741.8894117647, 'SafetyMarginPercentage': -0.03401360000000002}, {'BreakEvenVariable': 'CostPerAcquisition', 'FeasibilityStatus': 'CROSSOVER_FOUND', 'BreakEvenExpectedVariableValue': 24.0, 'BreakEvenExpectedResult': 1263823.5294117648, 'ThresholdVariableValue': 23.2653, 'ThresholdResult': 1304365.6735946818, 'SafetyMarginPercentage': -0.030612500000000004}, {'BreakEvenVariable': 'ConversionRate', 'FeasibilityStatus': 'CROSSOVER_FOUND', 'BreakEvenExpectedVariableValue': 0.12000000000000001, 'BreakEvenExpectedResult': 1263823.5294117648, 'ThresholdVariableValue': 0.1249, 'ThresholdResult': 1316246.3235294118, 'SafetyMarginPercentage': -0.04083333333333323}, {'BreakEvenVariable': 'ItemsPerOrder', 'FeasibilityStatus': 'CROSSOVER_FOUND', 'BreakEvenExpectedVariableValue': 3.0, 'BreakEvenExpectedResult': 1263823.5294117648, 'ThresholdVariableValue': 3.1224, 'ThresholdResult': 1316203.5294117648, 'SafetyMarginPercentage': -0.04079999999999995}]
